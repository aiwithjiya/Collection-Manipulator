# %% [markdown]
# #  👉 Collection Manipulator 📦

# %%
students = []

print("\nWelcome to the Student Data Organizer!")


def add_student():
    print("\nEnter student details:")

    student_id = input("Student ID: ")
    name = input("Name: ")
    age = input("Age: ")
    grade = input("Grade: ")
    dob = input("Date of Birth (YYYY-MM-DD): ")
    subjects = input("Subjects (comma-separated): ")

    student = {
        "id": student_id,
        "name": name,
        "age": age,
        "grade": grade,
        "dob": dob,
        "subjects": subjects
    }

    students.append(student)

    print("\nStudent added successfully!")


def display_students():

    if len(students) == 0:
        print("\nNo student records found.")
        return

    print("\n--- Display All Students ---")

    for student in students:
        print(
            "Student ID:", student["id"],
            "| Name:", student["name"],
            "| Age:", student["age"],
            "| Grade:", student["grade"],
            "| DOB:", student["dob"],
            "| Subjects:", student["subjects"]
        )


def update_student():

    student_id = input("\nEnter Student ID to update: ")

    for student in students:

        if student["id"] == student_id:

            print("\nEnter new details:")

            student["name"] = input("New Name: ")
            student["age"] = input("New Age: ")
            student["grade"] = input("New Grade: ")
            student["dob"] = input("New DOB (YYYY-MM-DD): ")
            student["subjects"] = input("New Subjects: ")

            print("\nStudent information updated successfully!")
            return

    print("\nStudent not found.")


def delete_student():

    student_id = input("\nEnter Student ID to delete: ")

    for student in students:

        if student["id"] == student_id:
            students.remove(student)

            print("\nStudent deleted successfully!")
            return

    print("\nStudent not found.")


def display_subjects():

    if len(students) == 0:
        print("\nNo subjects available.")
        return

    all_subjects = []

    for student in students:

        subject_list = student["subjects"].split(",")

        for subject in subject_list:

            subject = subject.strip()

            if subject not in all_subjects:
                all_subjects.append(subject)

    print("\n--- Subjects Offered ---")

    for subject in all_subjects:
        print(subject)


while True:

    print("\nSelect an option:")
    print("1. Add Student")
    print("2. Display All Students")
    print("3. Update Student Information")
    print("4. Delete Student")
    print("5. Display Subjects Offered")
    print("6. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_student()

    elif choice == "2":
        display_students()

    elif choice == "3":
        update_student()

    elif choice == "4":
        delete_student()

    elif choice == "5":
        display_subjects()

    elif choice == "6":
        print("\nExiting program...")
        print("Thank you!")
        break

    else:
        print("\nInvalid choice! Please try again.")
# Out:
# Welcome to the Student Data Organizer!
#
# Select an option:
# 1. Add Student
# 2. Display All Students
# 3. Update Student Information
# 4. Delete Student
# 5. Display Subjects Offered
# 6. Exit
# Enter your choice:  1
# Enter student details:
# Student ID:  101
# Name:  Alice
# Age:  18
# Grade:  B+
# Date of Birth (YYYY-MM-DD):  2008-04-19
# Subjects (comma-separated):  Social Science, Geography, History
# Student added successfully!
#
# Select an option:
# 1. Add Student
# 2. Display All Students
# 3. Update Student Information
# 4. Delete Student
# 5. Display Subjects Offered
# 6. Exit
# Enter your choice:  2
# --- Display All Students ---
# Student ID: 101 | Name: Alice | Age: 18 | Grade: B+ | DOB: 2008-04-19 | Subjects: Social Science, Geography, History
#
# Select an option:
# 1. Add Student
# 2. Display All Students
# 3. Update Student Information
# 4. Delete Student
# 5. Display Subjects Offered
# 6. Exit
# Enter your choice:  3
#
# Enter Student ID to update:  101
# Enter new details:
# New Name:  Jiya
# New Age:  20
# New Grade:  AB-
# New DOB (YYYY-MM-DD):  2006-01-30
# New Subjects:  English, Science, Maths
# Student information updated successfully!
#
# Select an option:
# 1. Add Student
# 2. Display All Students
# 3. Update Student Information
# 4. Delete Student
# 5. Display Subjects Offered
# 6. Exit
# Enter your choice:  4
#
# Enter Student ID to delete:  101
# Student deleted successfully!
#
# Select an option:
# 1. Add Student
# 2. Display All Students
# 3. Update Student Information
# 4. Delete Student
# 5. Display Subjects Offered
# 6. Exit
# Enter your choice:  5
# No subjects available.
#
# Select an option:
# 1. Add Student
# 2. Display All Students
# 3. Update Student Information
# 4. Delete Student
# 5. Display Subjects Offered
# 6. Exit
# Enter your choice:  6
# Exiting program...
# Thank you!
